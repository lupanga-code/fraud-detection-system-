# %%
import pandas as pd
import joblib

df = pd.read_csv("data/synthetic_dataset.csv")
model = joblib.load("models/fraud_detection_model.pkl")

print(model.predict(df[['Amount','Merchant','Location','Channel']]))
